# %%
from pathlib import Path

import numpy as np
import pandas as pd
import seaborn as sns

GPS = Path("/home/FCAM/juli/HRP/data/Final/GPS/GPS5_2020-02-26_all_matrix.csv")

# %%
"""
To get the kinase-specific scores for every potential phosphorylation site in the proteome
"""
df = pd.read_csv(GPS)
df
# Out:
#        substrate_id substrate_name substrate_acc  site              pep  \
# 0        A0AUZ9_105        KANSL1L        A0AUZ9  S105  QKKLGEPSCNKLKNI
# 1        A0AUZ9_205        KANSL1L        A0AUZ9  S205  KKIVPGHSNVPVSSS
# 2        A0AUZ9_462        KANSL1L        A0AUZ9  S462  PEQDFEMSPSSPTLL
# 3        A0AUZ9_464        KANSL1L        A0AUZ9  S464  QDFEMSPSSPTLLLR
# 4        A0AUZ9_519        KANSL1L        A0AUZ9  S519  NGIYRSASENLDELS
# ...             ...            ...           ...   ...              ...
# 246005    Q9Y6Y9_22           LY96        Q9Y6Y9   Y22  FTEAQKQYWVCNSSD
# 246006   Q9Y6Z7_141        COLEC10        Q9Y6Z7  S141  SIARLKTSMKFVKNV
# 246007   Q9Y6Z7_155        COLEC10        Q9Y6Z7  T155  VIAGIRETEEKFYYI
# 246008   Q9YNA8_181        ERVK-19        Q9YNA8  T181  SESKPRGTSRLPAGQ
# 246009   Q9YNA8_465        ERVK-19        Q9YNA8  S465  LQDVAQKSIAIEKAR
#
#                        AAK1  ABL1   ABL2                ACVRL1  \
# 0       -0.7959999999999999     -      -                -0.802
# 1                   -0.0327     -      -                -0.154
# 2                     0.002     -      -                 -1.26
# 3                     0.077     -      -                -0.426
# 4                     0.903     -      -                -0.645
# ...                     ...   ...    ...                   ...
# 246005                    -  -1.4  -3.85                     -
# 246006                -2.07     -      -  -0.19699999999999998
# 246007                0.575     -      -   -0.9790000000000001
# 246008                1.148     -      -                  0.59
# 246009                0.975     -      -                -0.735
#
#                       AKT1  ...                ULK2                ULK3  \
# 0                    5.636  ...               3.407                0.13
# 1                    3.997  ...              -0.235  1.6369999999999998
# 2       6.5920000000000005  ...  3.2430000000000003               -0.38
# 3                    5.256  ...  3.1860000000000004               -0.73
# 4                   11.737  ...               3.167               1.518
# ...                    ...  ...                 ...                 ...
# 246005                   -  ...                   -                   -
# 246006                5.14  ...               3.187              -0.495
# 246007               2.315  ...               3.305               -0.58
# 246008               3.483  ...  1.0490000000000002              -0.289
# 246009               4.088  ...               2.858               0.721
#
#                        VRK1    VRK2                    WNK1  \
# 0                      0.16   24.09  -8.759999999999999e-05
# 1                     0.159  46.489                0.000366
# 2       0.29600000000000004  13.935               -0.000365
# 3                      0.09  33.548                -0.00044
# 4                     0.047   -2.98               -0.000152
# ...                     ...     ...                     ...
# 246005                    -       -                       -
# 246006              -0.0712  16.753  0.00020299999999999997
# 246007                0.174  32.484  0.00038700000000000003
# 246008  0.11599999999999999   4.295  0.00011100000000000001
# 246009              -0.0921   -2.55                 0.00016
#
#                       WNK2                 WNK3                 WNK4   YES1  \
# 0                     2.92                 0.61                1.465      -
# 1                    0.847                0.841                0.691      -
# 2                    1.903                1.294               -0.415      -
# 3       0.5760000000000001                 0.98                0.498      -
# 4                   -0.938  -0.9740000000000001  -0.5870000000000001      -
# ...                    ...                  ...                  ...    ...
# 246005                   -                    -                    -  8.093
# 246006               1.255                0.304                2.469      -
# 246007             -0.0423               -0.634                0.175      -
# 246008               2.803   0.6890000000000001                0.374      -
# 246009               0.762                2.302                1.307      -
#
#                      ZAP70
# 0                        -
# 1                        -
# 2                        -
# 3                        -
# 4                        -
# ...                    ...
# 246005  0.8190000000000001
# 246006                   -
# 246007                   -
# 246008                   -
# 246009                   -
#
# [246010 rows x 314 columns]

# %%
"""
Different residue types  have different kinase families. Only model Y-sites 
"""
df_Y = df.loc[df["site"].str.startswith("Y")] # Filters rows where the site column starts with “Y”.
df_Y
# Out:
#        substrate_id substrate_name substrate_acc   site              pep AAK1  \
# 7        A0AUZ9_792        KANSL1L        A0AUZ9   Y792  AKLEKLQYKEILTPS    -
# 11       A0AV02_107        SLC12A8        A0AV02   Y107  SIGSGGVYSMISSVL    -
# 15       A0AVF1_167          TTC26        A0AVF1   Y167  IHYMRSHYQEAIDIY    -
# 16       A0AVF1_174          TTC26        A0AVF1   Y174  YQEAIDIYKRILLDN    -
# 22      A0AVI2_1801         FER1L5        A0AVI2  Y1801  CVQSQKDYIWSLDAT    -
# ...             ...            ...           ...    ...              ...  ...
# 245974   Q9Y6Y1_152         CAMTA1        Q9Y6Y1   Y152  VECLYGCYVHSSIIP    -
# 245988   Q9Y6Y8_637        SEC23IP        Q9Y6Y8   Y637  KLTLDESYDLVVENK    -
# 246003   Q9Y6Y8_935        SEC23IP        Q9Y6Y8   Y935  DFSKDEDYLGKVGML    -
# 246004   Q9Y6Y9_131           LY96        Q9Y6Y9   Y131  IKFSKGKYKCVVEAI    -
# 246005    Q9Y6Y9_22           LY96        Q9Y6Y9    Y22  FTEAQKQYWVCNSSD    -
#
#                       ABL1                ABL2 ACVRL1 AKT1  ... ULK2 ULK3  \
# 7                   -0.447               0.924      -    -  ...    -    -
# 11                   1.676              18.583      -    -  ...    -    -
# 15       5.132999999999999              18.454      -    -  ...    -    -
# 16                   8.081  10.857000000000001      -    -  ...    -    -
# 22                    1.76               6.075      -    -  ...    -    -
# ...                    ...                 ...    ...  ...  ...  ...  ...
# 245974  3.7510000000000003               -13.8      -    -  ...    -    -
# 245988               2.391               6.125      -    -  ...    -    -
# 246003               3.173              16.523      -    -  ...    -    -
# 246004               -2.37               6.606      -    -  ...    -    -
# 246005                -1.4               -3.85      -    -  ...    -    -
#
#        VRK1 VRK2 WNK1 WNK2 WNK3 WNK4               YES1               ZAP70
# 7         -    -    -    -    -    -             11.945               5.285
# 11        -    -    -    -    -    -              5.585              -0.332
# 15        -    -    -    -    -    -              4.062               1.726
# 16        -    -    -    -    -    -              -1.97               -2.92
# 22        -    -    -    -    -    -  5.343999999999999              -0.225
# ...     ...  ...  ...  ...  ...  ...                ...                 ...
# 245974    -    -    -    -    -    -              -16.7              -0.386
# 245988    -    -    -    -    -    -             21.799               2.351
# 246003    -    -    -    -    -    -               7.12  7.5820000000000025
# 246004    -    -    -    -    -    -  8.177999999999999               -4.52
# 246005    -    -    -    -    -    -              8.093  0.8190000000000001
#
# [41422 rows x 314 columns]

# %%
"""
Loops through every kinase column, checks if the column is entirely “-”, collects those names, then drops them. We are doing this because columns with zero information hurt both runtime and statistics. They are useless for analysis
"""
kinases = list(df.columns)[5:] # all kinase columns
droped = []
for kinase in kinases:
    if np.all(df_Y[kinase] == "-"): # column is **all** dashes
        droped.append(kinase)
df_Y = df_Y.drop(droped, axis=1)
df_Y
# Out:
#        substrate_id substrate_name substrate_acc   site              pep  \
# 7        A0AUZ9_792        KANSL1L        A0AUZ9   Y792  AKLEKLQYKEILTPS
# 11       A0AV02_107        SLC12A8        A0AV02   Y107  SIGSGGVYSMISSVL
# 15       A0AVF1_167          TTC26        A0AVF1   Y167  IHYMRSHYQEAIDIY
# 16       A0AVF1_174          TTC26        A0AVF1   Y174  YQEAIDIYKRILLDN
# 22      A0AVI2_1801         FER1L5        A0AVI2  Y1801  CVQSQKDYIWSLDAT
# ...             ...            ...           ...    ...              ...
# 245974   Q9Y6Y1_152         CAMTA1        Q9Y6Y1   Y152  VECLYGCYVHSSIIP
# 245988   Q9Y6Y8_637        SEC23IP        Q9Y6Y8   Y637  KLTLDESYDLVVENK
# 246003   Q9Y6Y8_935        SEC23IP        Q9Y6Y8   Y935  DFSKDEDYLGKVGML
# 246004   Q9Y6Y9_131           LY96        Q9Y6Y9   Y131  IKFSKGKYKCVVEAI
# 246005    Q9Y6Y9_22           LY96        Q9Y6Y9    Y22  FTEAQKQYWVCNSSD
#
#                       ABL1                ABL2                  ALK  \
# 7                   -0.447               0.924                2.292
# 11                   1.676              18.583                1.879
# 15       5.132999999999999              18.454                0.579
# 16                   8.081  10.857000000000001               -0.358
# 22                    1.76               6.075                0.815
# ...                    ...                 ...                  ...
# 245974  3.7510000000000003               -13.8                0.998
# 245988               2.391               6.125                0.614
# 246003               3.173              16.523                0.779
# 246004               -2.37               6.606  -0.8590000000000001
# 246005                -1.4               -3.85                0.993
#
#                            AXL                BAZ1B  ...                 RET  \
# 7                        0.003                 -2.4  ...  33.849000000000004
# 11                    -0.00021                -2.13  ...              12.952
# 15                   -0.000685                 -2.9  ...              10.882
# 16                    0.000505                 -2.7  ...              24.015
# 22      -0.0005769999999999999                -1.65  ...              32.912
# ...                        ...                  ...  ...                 ...
# 245974               -0.000332                -1.87  ...               2.903
# 245988                   0.004                -2.63  ...               8.274
# 246003                   0.002                -2.18  ...              19.825
# 246004  -0.0006490000000000001  -0.7829999999999999  ...              19.575
# 246005               -0.000128                -1.44  ...               9.067
#
#                        SRC                 SYK      TEC                  TEK  \
# 7                    17.65   8.347000000000001  123.684               -0.256
# 11                  22.646              13.093   41.323                1.127
# 15                  19.611               11.47  159.026                0.742
# 16                  19.382              11.162   27.822                 0.18
# 22                  18.131               8.467  142.715  0.20199999999999999
# ...                    ...                 ...      ...                  ...
# 245974  15.315999999999999               6.566    -61.3                0.017
# 245988  22.851999999999997  17.055999999999994  177.774  0.08199999999999999
# 246003              18.733              16.697  210.518                 0.24
# 246004              15.714   8.597999999999999  193.317              -0.0904
# 246005              19.451               2.408  143.631                0.445
#
#                           TNK2    TXK                TYK2               YES1  \
# 7                     2.95e-06  1.169  24.308000000000003             11.945
# 11                    5.67e-06  1.567  10.437999999999999              5.585
# 15                    5.35e-06  0.259               8.639              4.062
# 16                    2.09e-06   1.28              16.336              -1.97
# 22                       3e-06  -0.29               9.274  5.343999999999999
# ...                        ...    ...                 ...                ...
# 245974                3.43e-07  0.943               -10.8              -16.7
# 245988                4.87e-06  2.246               -8.06             21.799
# 246003  5.0999999999999995e-06   0.01               2.372               7.12
# 246004                2.59e-06  1.208               4.999  8.177999999999999
# 246005                3.39e-07  1.073              21.397              8.093
#
#                      ZAP70
# 7                    5.285
# 11                  -0.332
# 15                   1.726
# 16                   -2.92
# 22                  -0.225
# ...                    ...
# 245974              -0.386
# 245988               2.351
# 246003  7.5820000000000025
# 246004               -4.52
# 246005  0.8190000000000001
#
# [41422 rows x 70 columns]

# %%
"""
load the raw dataset
"""

phos_df = pd.read_csv(
    "/home/FCAM/juli/HRP/Phosphorylation_site_dataset", 
    sep="\t",
)
phos_df
# Out:
#               PROTEIN  ACC_ID           GENE HU_CHR_LOC MOD_RSD  SITE_GRP_ID  \
# 0       1110035H17Rik  Q9CTA4  1110035H17Rik        NaN   S10-p      7231581
# 1       1110035H17Rik  Q9CTA4  1110035H17Rik        NaN   T11-p      7231583
# 2         14-3-3 beta  P31946          YWHAB    20q13.1    T2-p     15718712
# 3         14-3-3 beta  Q9CQV8          Ywhab        NaN    T2-p     15718712
# 4         14-3-3 beta  P31946          YWHAB    20q13.1    S6-p     15718709
# ...               ...     ...            ...        ...     ...          ...
# 334768           ZZZ3  Q8IYH5           ZZZ3     1p31.1  S606-p     23077718
# 334769           ZZZ3  Q6KAQ7           Zzz3        NaN  S613-p     23077718
# 334770           ZZZ3  Q8IYH5           ZZZ3     1p31.1  Y670-p     23077724
# 334771           ZZZ3  Q8IYH5           ZZZ3     1p31.1  S677-p     23077721
# 334772           ZZZ3  Q8IYH5           ZZZ3     1p31.1  S777-p     41455930
#
#        ORGANISM   MW_kD           DOMAIN     SITE_+/-7_AA  LT_LIT  MS_LIT  \
# 0         mouse   24.31              NaN  RPPPGSRstVAQSPP     NaN     1.0
# 1         mouse   24.31              NaN  PPPGSRstVAQSPPQ     NaN     1.0
# 2         human   28.08              NaN  ______MtMDksELV     NaN     1.0
# 3         mouse   28.09              NaN  ______MtMDksELV     NaN     1.0
# 4         human   28.08           14-3-3  __MtMDksELVQkAk     NaN     4.0
# ...         ...     ...              ...              ...     ...     ...
# 334768    human  102.02              NaN  GLPARPksPLDPKKD     NaN     2.0
# 334769    mouse  102.31              NaN  GLPARPKsPLDPKKD     NaN     1.0
# 334770    human  102.02  Myb_DNA-binding  LEQLLIKyPPEEVEs     NaN     NaN
# 334771    human  102.02  Myb_DNA-binding  yPPEEVEsRRWQKIA     NaN     NaN
# 334772    human  102.02              NaN  NTAVEDAsDDESIPI     NaN     1.0
#
#         MS_CST CST_CAT#
# 0          NaN      NaN
# 1          NaN      NaN
# 2          1.0      NaN
# 3          NaN      NaN
# 4          NaN      NaN
# ...        ...      ...
# 334768     4.0      NaN
# 334769     NaN      NaN
# 334770     1.0      NaN
# 334771     1.0      NaN
# 334772     NaN      NaN
#
# [334773 rows x 14 columns]

# %%
"""
Keep human tyrosine sites only
"""

phos_df = phos_df.loc[phos_df["MOD_RSD"].str.startswith("Y")]
phos_df = phos_df.loc[phos_df["ORGANISM"] == "human"]
phos_df
# Out:
#             PROTEIN  ACC_ID   GENE HU_CHR_LOC  MOD_RSD  SITE_GRP_ID ORGANISM  \
# 6       14-3-3 beta  P31946  YWHAB    20q13.1    Y21-p      3426383    human
# 13      14-3-3 beta  P31946  YWHAB    20q13.1    Y50-p     12432961    human
# 21      14-3-3 beta  P31946  YWHAB    20q13.1   Y106-p      9407297    human
# 24      14-3-3 beta  P31946  YWHAB    20q13.1   Y120-p      3665374    human
# 25      14-3-3 beta  P31946  YWHAB    20q13.1   Y127-p      3549169    human
# ...             ...     ...    ...        ...      ...          ...      ...
# 334683        Zyxin  Q15942    ZYX       7q32   Y316-p       454274    human
# 334695        ZZEF1  O43149  ZZEF1    17p13.2   Y702-p       479230    human
# 334698        ZZEF1  O43149  ZZEF1    17p13.2   Y976-p       484695    human
# 334744        ZZEF1  O43149  ZZEF1    17p13.2  Y2494-p     22778456    human
# 334770         ZZZ3  Q8IYH5   ZZZ3     1p31.1   Y670-p     23077724    human
#
#          MW_kD           DOMAIN     SITE_+/-7_AA  LT_LIT  MS_LIT  MS_CST  \
# 6        28.08           14-3-3  LAEQAERyDDMAAAM     NaN     NaN     3.0
# 13       28.08           14-3-3  RNLLsVAykNVVGAR     NaN     2.0     5.0
# 21       28.08           14-3-3  VLELLDkyLIPNATQ     NaN     NaN     1.0
# 24       28.08           14-3-3  QPEskVFyLkMkGDy     NaN     NaN     1.0
# 25       28.08           14-3-3  yLkMkGDyFRyLsEV     NaN     1.0     4.0
# ...        ...              ...              ...     ...     ...     ...
# 334683   61.28              NaN  PQPPsFtyAQQREKP     NaN     7.0   198.0
# 334695  331.08              NaN  QGLTISGyLRPARAE     NaN     NaN     1.0
# 334698  331.08              NaN  GSLLSWCyLQLKSTD     NaN     1.0     NaN
# 334744  331.08              NaN  LQMKkTDyFFLEVQk     NaN     NaN     7.0
# 334770  102.02  Myb_DNA-binding  LEQLLIKyPPEEVEs     NaN     NaN     1.0
#
#        CST_CAT#
# 6           NaN
# 13          NaN
# 21          NaN
# 24          NaN
# 25          NaN
# ...         ...
# 334683      NaN
# 334695      NaN
# 334698      NaN
# 334744      NaN
# 334770      NaN
#
# [37138 rows x 14 columns]

# %%
"""
Converts Y106-p to Y106. Makes sites comparable with GPS notation.
"""
phos_df["MOD_RSD"] = phos_df["MOD_RSD"].str.removesuffix("-p")
phos_df
# Out:
#             PROTEIN  ACC_ID   GENE HU_CHR_LOC MOD_RSD  SITE_GRP_ID ORGANISM  \
# 6       14-3-3 beta  P31946  YWHAB    20q13.1     Y21      3426383    human
# 13      14-3-3 beta  P31946  YWHAB    20q13.1     Y50     12432961    human
# 21      14-3-3 beta  P31946  YWHAB    20q13.1    Y106      9407297    human
# 24      14-3-3 beta  P31946  YWHAB    20q13.1    Y120      3665374    human
# 25      14-3-3 beta  P31946  YWHAB    20q13.1    Y127      3549169    human
# ...             ...     ...    ...        ...     ...          ...      ...
# 334683        Zyxin  Q15942    ZYX       7q32    Y316       454274    human
# 334695        ZZEF1  O43149  ZZEF1    17p13.2    Y702       479230    human
# 334698        ZZEF1  O43149  ZZEF1    17p13.2    Y976       484695    human
# 334744        ZZEF1  O43149  ZZEF1    17p13.2   Y2494     22778456    human
# 334770         ZZZ3  Q8IYH5   ZZZ3     1p31.1    Y670     23077724    human
#
#          MW_kD           DOMAIN     SITE_+/-7_AA  LT_LIT  MS_LIT  MS_CST  \
# 6        28.08           14-3-3  LAEQAERyDDMAAAM     NaN     NaN     3.0
# 13       28.08           14-3-3  RNLLsVAykNVVGAR     NaN     2.0     5.0
# 21       28.08           14-3-3  VLELLDkyLIPNATQ     NaN     NaN     1.0
# 24       28.08           14-3-3  QPEskVFyLkMkGDy     NaN     NaN     1.0
# 25       28.08           14-3-3  yLkMkGDyFRyLsEV     NaN     1.0     4.0
# ...        ...              ...              ...     ...     ...     ...
# 334683   61.28              NaN  PQPPsFtyAQQREKP     NaN     7.0   198.0
# 334695  331.08              NaN  QGLTISGyLRPARAE     NaN     NaN     1.0
# 334698  331.08              NaN  GSLLSWCyLQLKSTD     NaN     1.0     NaN
# 334744  331.08              NaN  LQMKkTDyFFLEVQk     NaN     NaN     7.0
# 334770  102.02  Myb_DNA-binding  LEQLLIKyPPEEVEs     NaN     NaN     1.0
#
#        CST_CAT#
# 6           NaN
# 13          NaN
# 21          NaN
# 24          NaN
# 25          NaN
# ...         ...
# 334683      NaN
# 334695      NaN
# 334698      NaN
# 334744      NaN
# 334770      NaN
#
# [37138 rows x 14 columns]

# %%
"""
Creates a unique 2-key index 
"""

src = phos_df.set_index(["ACC_ID", "MOD_RSD"])
src
# Out:
#                     PROTEIN   GENE HU_CHR_LOC  SITE_GRP_ID ORGANISM   MW_kD  \
# ACC_ID MOD_RSD
# P31946 Y21-p    14-3-3 beta  YWHAB    20q13.1      3426383    human   28.08
#        Y50-p    14-3-3 beta  YWHAB    20q13.1     12432961    human   28.08
#        Y106-p   14-3-3 beta  YWHAB    20q13.1      9407297    human   28.08
#        Y120-p   14-3-3 beta  YWHAB    20q13.1      3665374    human   28.08
#        Y127-p   14-3-3 beta  YWHAB    20q13.1      3549169    human   28.08
# ...                     ...    ...        ...          ...      ...     ...
# Q15942 Y316-p         Zyxin    ZYX       7q32       454274    human   61.28
# O43149 Y702-p         ZZEF1  ZZEF1    17p13.2       479230    human  331.08
#        Y976-p         ZZEF1  ZZEF1    17p13.2       484695    human  331.08
#        Y2494-p        ZZEF1  ZZEF1    17p13.2     22778456    human  331.08
# Q8IYH5 Y670-p          ZZZ3   ZZZ3     1p31.1     23077724    human  102.02
#
#                          DOMAIN     SITE_+/-7_AA  LT_LIT  MS_LIT  MS_CST  \
# ACC_ID MOD_RSD
# P31946 Y21-p             14-3-3  LAEQAERyDDMAAAM     NaN     NaN     3.0
#        Y50-p             14-3-3  RNLLsVAykNVVGAR     NaN     2.0     5.0
#        Y106-p            14-3-3  VLELLDkyLIPNATQ     NaN     NaN     1.0
#        Y120-p            14-3-3  QPEskVFyLkMkGDy     NaN     NaN     1.0
#        Y127-p            14-3-3  yLkMkGDyFRyLsEV     NaN     1.0     4.0
# ...                         ...              ...     ...     ...     ...
# Q15942 Y316-p               NaN  PQPPsFtyAQQREKP     NaN     7.0   198.0
# O43149 Y702-p               NaN  QGLTISGyLRPARAE     NaN     NaN     1.0
#        Y976-p               NaN  GSLLSWCyLQLKSTD     NaN     1.0     NaN
#        Y2494-p              NaN  LQMKkTDyFFLEVQk     NaN     NaN     7.0
# Q8IYH5 Y670-p   Myb_DNA-binding  LEQLLIKyPPEEVEs     NaN     NaN     1.0
#
#                CST_CAT#
# ACC_ID MOD_RSD
# P31946 Y21-p        NaN
#        Y50-p        NaN
#        Y106-p       NaN
#        Y120-p       NaN
#        Y127-p       NaN
# ...                 ...
# Q15942 Y316-p       NaN
# O43149 Y702-p       NaN
#        Y976-p       NaN
#        Y2494-p      NaN
# Q8IYH5 Y670-p       NaN
#
# [37138 rows x 12 columns]

# %%
# Renames columns 

dst = df_Y.rename({"substrate_acc":"ACC_ID", "site": "MOD_RSD"}, axis=1)
dst = dst.set_index(["ACC_ID", "MOD_RSD"])
dst
# Out:
#                substrate_id substrate_name              pep  \
# ACC_ID MOD_RSD
# A0AUZ9 Y792      A0AUZ9_792        KANSL1L  AKLEKLQYKEILTPS
# A0AV02 Y107      A0AV02_107        SLC12A8  SIGSGGVYSMISSVL
# A0AVF1 Y167      A0AVF1_167          TTC26  IHYMRSHYQEAIDIY
#        Y174      A0AVF1_174          TTC26  YQEAIDIYKRILLDN
# A0AVI2 Y1801    A0AVI2_1801         FER1L5  CVQSQKDYIWSLDAT
# ...                     ...            ...              ...
# Q9Y6Y1 Y152      Q9Y6Y1_152         CAMTA1  VECLYGCYVHSSIIP
# Q9Y6Y8 Y637      Q9Y6Y8_637        SEC23IP  KLTLDESYDLVVENK
#        Y935      Q9Y6Y8_935        SEC23IP  DFSKDEDYLGKVGML
# Q9Y6Y9 Y131      Q9Y6Y9_131           LY96  IKFSKGKYKCVVEAI
#        Y22        Q9Y6Y9_22           LY96  FTEAQKQYWVCNSSD
#
#                               ABL1                ABL2                  ALK  \
# ACC_ID MOD_RSD
# A0AUZ9 Y792                 -0.447               0.924                2.292
# A0AV02 Y107                  1.676              18.583                1.879
# A0AVF1 Y167      5.132999999999999              18.454                0.579
#        Y174                  8.081  10.857000000000001               -0.358
# A0AVI2 Y1801                  1.76               6.075                0.815
# ...                            ...                 ...                  ...
# Q9Y6Y1 Y152     3.7510000000000003               -13.8                0.998
# Q9Y6Y8 Y637                  2.391               6.125                0.614
#        Y935                  3.173              16.523                0.779
# Q9Y6Y9 Y131                  -2.37               6.606  -0.8590000000000001
#        Y22                    -1.4               -3.85                0.993
#
#                                    AXL                BAZ1B       BLK  \
# ACC_ID MOD_RSD
# A0AUZ9 Y792                      0.003                 -2.4  0.000152
# A0AV02 Y107                   -0.00021                -2.13   -0.0832
# A0AVF1 Y167                  -0.000685                 -2.9     0.584
#        Y174                   0.000505                 -2.7     1.325
# A0AVI2 Y1801    -0.0005769999999999999                -1.65     0.285
# ...                                ...                  ...       ...
# Q9Y6Y1 Y152                  -0.000332                -1.87      0.32
# Q9Y6Y8 Y637                      0.004                -2.63     0.368
#        Y935                      0.002                -2.18    -0.604
# Q9Y6Y9 Y131     -0.0006490000000000001  -0.7829999999999999     0.376
#        Y22                   -0.000128                -1.44     1.604
#
#                                 BMX  ...                 RET  \
# ACC_ID MOD_RSD                       ...
# A0AUZ9 Y792                   0.426  ...  33.849000000000004
# A0AV02 Y107                   1.662  ...              12.952
# A0AVF1 Y167                   0.875  ...              10.882
#        Y174                   2.551  ...              24.015
# A0AVI2 Y1801                  2.043  ...              32.912
# ...                             ...  ...                 ...
# Q9Y6Y1 Y152     0.33899999999999997  ...               2.903
# Q9Y6Y8 Y637      3.8569999999999998  ...               8.274
#        Y935                  -0.535  ...              19.825
# Q9Y6Y9 Y131      1.5319999999999998  ...              19.575
#        Y22       0.6559999999999999  ...               9.067
#
#                                SRC                 SYK      TEC  \
# ACC_ID MOD_RSD
# A0AUZ9 Y792                  17.65   8.347000000000001  123.684
# A0AV02 Y107                 22.646              13.093   41.323
# A0AVF1 Y167                 19.611               11.47  159.026
#        Y174                 19.382              11.162   27.822
# A0AVI2 Y1801                18.131               8.467  142.715
# ...                            ...                 ...      ...
# Q9Y6Y1 Y152     15.315999999999999               6.566    -61.3
# Q9Y6Y8 Y637     22.851999999999997  17.055999999999994  177.774
#        Y935                 18.733              16.697  210.518
# Q9Y6Y9 Y131                 15.714   8.597999999999999  193.317
#        Y22                  19.451               2.408  143.631
#
#                                 TEK                    TNK2    TXK  \
# ACC_ID MOD_RSD
# A0AUZ9 Y792                  -0.256                2.95e-06  1.169
# A0AV02 Y107                   1.127                5.67e-06  1.567
# A0AVF1 Y167                   0.742                5.35e-06  0.259
#        Y174                    0.18                2.09e-06   1.28
# A0AVI2 Y1801    0.20199999999999999                   3e-06  -0.29
# ...                             ...                     ...    ...
# Q9Y6Y1 Y152                   0.017                3.43e-07  0.943
# Q9Y6Y8 Y637     0.08199999999999999                4.87e-06  2.246
#        Y935                    0.24  5.0999999999999995e-06   0.01
# Q9Y6Y9 Y131                 -0.0904                2.59e-06  1.208
#        Y22                    0.445                3.39e-07  1.073
#
#                               TYK2               YES1               ZAP70
# ACC_ID MOD_RSD
# A0AUZ9 Y792     24.308000000000003             11.945               5.285
# A0AV02 Y107     10.437999999999999              5.585              -0.332
# A0AVF1 Y167                  8.639              4.062               1.726
#        Y174                 16.336              -1.97               -2.92
# A0AVI2 Y1801                 9.274  5.343999999999999              -0.225
# ...                            ...                ...                 ...
# Q9Y6Y1 Y152                  -10.8              -16.7              -0.386
# Q9Y6Y8 Y637                  -8.06             21.799               2.351
#        Y935                  2.372               7.12  7.5820000000000025
# Q9Y6Y9 Y131                  4.999  8.177999999999999               -4.52
#        Y22                  21.397              8.093  0.8190000000000001
#
# [41422 rows x 68 columns]

# %%
"""
Adds the 65 kinase-score columns + 4 GPS metadata cols onto the PSP scaffold. Produces a table for analysis
"""
merged = src.join(dst)
merged
# Out:
#                     PROTEIN   GENE HU_CHR_LOC  SITE_GRP_ID ORGANISM   MW_kD  \
# ACC_ID MOD_RSD
# P31946 Y21-p    14-3-3 beta  YWHAB    20q13.1      3426383    human   28.08
#        Y50-p    14-3-3 beta  YWHAB    20q13.1     12432961    human   28.08
#        Y106-p   14-3-3 beta  YWHAB    20q13.1      9407297    human   28.08
#        Y120-p   14-3-3 beta  YWHAB    20q13.1      3665374    human   28.08
#        Y127-p   14-3-3 beta  YWHAB    20q13.1      3549169    human   28.08
# ...                     ...    ...        ...          ...      ...     ...
# Q15942 Y316-p         Zyxin    ZYX       7q32       454274    human   61.28
# O43149 Y702-p         ZZEF1  ZZEF1    17p13.2       479230    human  331.08
#        Y976-p         ZZEF1  ZZEF1    17p13.2       484695    human  331.08
#        Y2494-p        ZZEF1  ZZEF1    17p13.2     22778456    human  331.08
# Q8IYH5 Y670-p          ZZZ3   ZZZ3     1p31.1     23077724    human  102.02
#
#                          DOMAIN     SITE_+/-7_AA  LT_LIT  MS_LIT  ...  RET  \
# ACC_ID MOD_RSD                                                    ...
# P31946 Y21-p             14-3-3  LAEQAERyDDMAAAM     NaN     NaN  ...  NaN
#        Y50-p             14-3-3  RNLLsVAykNVVGAR     NaN     2.0  ...  NaN
#        Y106-p            14-3-3  VLELLDkyLIPNATQ     NaN     NaN  ...  NaN
#        Y120-p            14-3-3  QPEskVFyLkMkGDy     NaN     NaN  ...  NaN
#        Y127-p            14-3-3  yLkMkGDyFRyLsEV     NaN     1.0  ...  NaN
# ...                         ...              ...     ...     ...  ...  ...
# Q15942 Y316-p               NaN  PQPPsFtyAQQREKP     NaN     7.0  ...  NaN
# O43149 Y702-p               NaN  QGLTISGyLRPARAE     NaN     NaN  ...  NaN
#        Y976-p               NaN  GSLLSWCyLQLKSTD     NaN     1.0  ...  NaN
#        Y2494-p              NaN  LQMKkTDyFFLEVQk     NaN     NaN  ...  NaN
# Q8IYH5 Y670-p   Myb_DNA-binding  LEQLLIKyPPEEVEs     NaN     NaN  ...  NaN
#
#                 SRC  SYK  TEC  TEK TNK2  TXK TYK2 YES1 ZAP70
# ACC_ID MOD_RSD
# P31946 Y21-p    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
#        Y50-p    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
#        Y106-p   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
#        Y120-p   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
#        Y127-p   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
# ...             ...  ...  ...  ...  ...  ...  ...  ...   ...
# Q15942 Y316-p   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
# O43149 Y702-p   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
#        Y976-p   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
#        Y2494-p  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
# Q8IYH5 Y670-p   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
#
# [37138 rows x 80 columns]

# %%
merged.to_csv("phossite_gps.csv")

# %%
def get_embedding(phospho_group_id, *, df = merged):
    """ return embedding as a numpy array, based on phospho group id
    """

    cols = ['ABL1', 'ABL2', 'ALK', 'AXL', 'BAZ1B', 'BLK', 'BMX', 'BTK', 'CSF1R',
       'CSK', 'DDR2', 'EGFR', 'EPHA2', 'EPHA3', 'EPHA4', 'EPHA8', 'EPHB1',
       'EPHB2', 'ERBB2', 'ERBB4', 'FER', 'FES', 'FGFR1', 'FGFR2', 'FGFR3',
       'FGFR4', 'FGR', 'FLT1', 'FLT3', 'FLT4', 'FRK', 'FYN', 'HCK', 'IGF1R',
       'INSR', 'ITK', 'JAK1', 'JAK2', 'JAK3', 'KDR', 'KIT', 'LCK', 'LYN',
       'MATK', 'MERTK', 'MET', 'MST1R', 'MUSK', 'NTRK1', 'NTRK2', 'PDGFRA',
       'PDGFRB', 'PTK2', 'PTK2B', 'PTK6', 'RET', 'SRC', 'SYK', 'TEC', 'TEK',
       'TNK2', 'TXK', 'TYK2', 'YES1', 'ZAP70']

    rows = df.loc[df["SITE_GRP_ID"] == phospho_group_id]
    
    if len(rows) == 0:
        raise ValueError("Invalid group id")

    features = rows[cols].to_numpy().astype(float)

    features = features.mean(axis = 0)

    return features
